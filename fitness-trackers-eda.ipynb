# %% [markdown]
# <p style="font-family: Brush Script MT; line-height: 3; font-size: 32px; letter-spacing: 1px; text-align: center; color: #e50b00">Exploratory Data Analysis of Fitness Trackers available in the Indian Market</p>

# %% [markdown]
# ![Fitness trackers(4).jpg](attachment:54895319-34a4-4676-9752-52a135b804b0.jpg)

# %% [markdown]
# <p style="font-family: Georgia; line-height: 2;color:#f94144; font-size: 17px; font-weight: bold; letter-spacing: 2px; text-align: center; ">This notebook uses a fitness tracker dataset. The data has been collected from an e-commerce website Flipkart using webscraping technique.</p>

# %% [markdown]
# <h3 style="font-family: Trebuchet MS;background-color:#f7a072;color:#3a0ca3;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;letter-spacing: 2px;"><strong><centre>Dataset Details </centre></strong></h3>

# %% [markdown]
# This dataset contains `610` samples with `11` attributes. There are some missing values in this dataset.
# Here are the columns in this dataset-
#
# 1.   **Brand Name**: This indicates the manufacturer of the product (fitness tracker)
# 2.   **Device Type**: This has two categories- FitnessBand and Smartwatch
# 3.  **Model Name**: This indicates the variant/Product Name
# 4.   **Color**: This includes the color of the Strap/Body of the fitness tracker
# 5.   **Selling Price**: This column has the Selling Price or the Discounted Price of the fitness tracker
# 6.   **Original Price**: This includes the Original Price of the product from the manufacturer.
# 7.   **Display**: This categorical variable shows the type of display for the fitness tracker. eg: AMOLED, LCD,OLED, etc.
# 8.   **Rating (Out of 5)**: Average customer ratings on a scale of 5.
# 9.   **Strap Material**: Details of the material used for the strap of the fitness tracker.
# 10.  **Average Battery Life (in days)**: Quoted average battery life from the manufacturer based on the individual product pages. (It is not the scraped data)
# 11.  **Reviews**:  count of product reviews received.

# %% [markdown]
# <h3 style="font-family: Trebuchet MS;background-color:#f7a072;color:#3a0ca3;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;letter-spacing: 2px;"><strong><centre>Importing Libraries </centre></strong></h3>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h3 style="font-family: Trebuchet MS;background-color:#f7a072;color:#3a0ca3;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;letter-spacing: 2px;"><strong><centre>Importing & Reading the dataset 📝  </centre></strong></h3>

# %%
df=pd.read_csv('../input/fitness-trackers-products-ecommerce/Fitness_trackers_updated.csv',thousands=',')
df.head()
# Out:
#   Brand Name  Device Type    Model Name  Color  Selling Price  Original Price  \
# 0     Xiaomi  FitnessBand  Smart Band 5  Black           2499            2999
# 1     Xiaomi  FitnessBand  Smart Band 4  Black           2099            2499
# 2     Xiaomi  FitnessBand      HMSH01GE  Black           1722            2099
# 3     Xiaomi  FitnessBand  Smart Band 5  Black           2469            2999
# 4     Xiaomi  FitnessBand        Band 3  Black           1799            2199
#
#           Display  Rating (Out of 5)              Strap Material  \
# 0  AMOLED Display                4.1  Thermoplastic polyurethane
# 1  AMOLED Display                4.2  Thermoplastic polyurethane
# 2     LCD Display                3.5                     Leather
# 3  AMOLED Display                4.1  Thermoplastic polyurethane
# 4    OLED Display                4.3                     Plastic
#
#    Average Battery Life (in days)  Reviews
# 0                              14      NaN
# 1                              14      NaN
# 2                              14      NaN
# 3                              14      NaN
# 4                               7      NaN

# %%
#check missing values 
df.isna().sum().sort_values(ascending=False)
# Out:
# Reviews                           496
# Rating (Out of 5)                  56
# Brand Name                          0
# Device Type                         0
# Model Name                          0
# Color                               0
# Selling Price                       0
# Original Price                      0
# Display                             0
# Strap Material                      0
# Average Battery Life (in days)      0
# dtype: int64

# %%
#replace NaN values
df=df.fillna(0)
df.iloc[:5]
# Out:
#   Brand Name  Device Type    Model Name  Color  Selling Price  Original Price  \
# 0     Xiaomi  FitnessBand  Smart Band 5  Black           2499            2999
# 1     Xiaomi  FitnessBand  Smart Band 4  Black           2099            2499
# 2     Xiaomi  FitnessBand      HMSH01GE  Black           1722            2099
# 3     Xiaomi  FitnessBand  Smart Band 5  Black           2469            2999
# 4     Xiaomi  FitnessBand        Band 3  Black           1799            2199
#
#           Display  Rating (Out of 5)              Strap Material  \
# 0  AMOLED Display                4.1  Thermoplastic polyurethane
# 1  AMOLED Display                4.2  Thermoplastic polyurethane
# 2     LCD Display                3.5                     Leather
# 3  AMOLED Display                4.1  Thermoplastic polyurethane
# 4    OLED Display                4.3                     Plastic
#
#    Average Battery Life (in days)  Reviews
# 0                              14      0.0
# 1                              14      0.0
# 2                              14      0.0
# 3                              14      0.0
# 4                               7      0.0

# %%
df.shape
# Out:
# (610, 11)

# %%
#distribution of data
df.describe().T
# Out:
#                                 count          mean           std     min  \
# Selling Price                   610.0  20706.859016  19803.690357   799.0
# Original Price                  610.0  23977.503279  20242.634014  1599.0
# Rating (Out of 5)               610.0      3.810492      1.277603     0.0
# Average Battery Life (in days)  610.0      8.926230      7.632107     1.0
# Reviews                         610.0    363.140984   2190.626386     0.0
#
#                                     25%      50%       75%       max
# Selling Price                    6995.0  14999.0  27467.50  122090.0
# Original Price                  10249.0  18995.0  31416.75  122090.0
# Rating (Out of 5)                   3.9      4.2      4.50       5.0
# Average Battery Life (in days)      2.0      7.0     14.00      45.0
# Reviews                             0.0      0.0      0.00   23426.0

# %%
#check for data types
df.dtypes
# Out:
# Brand Name                         object
# Device Type                        object
# Model Name                         object
# Color                              object
# Selling Price                       int64
# Original Price                      int64
# Display                            object
# Rating (Out of 5)                 float64
# Strap Material                     object
# Average Battery Life (in days)      int64
# Reviews                           float64
# dtype: object

# %% [markdown]
# <h3 style="font-family: Trebuchet MS;background-color:#f7a072;color:#3a0ca3;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;letter-spacing: 2px;"><strong><centre>EDA 🔍  </centre></strong></h3>

# %%
sns.set_style("white")
sns.pairplot(df, hue='Brand Name')

# %%
# count of products
df['Brand Name'].groupby(df['Device Type']).count().sort_values(ascending=False)
# Out:
# Device Type
# Smartwatch     533
# FitnessBand     77
# Name: Brand Name, dtype: int64

# %%
#count of brands
df['Brand Name'].nunique()
# Out:
# 25

# %%
df['Brand Name'].groupby(df['Brand Name']).count().sort_values(ascending=False)
# Out:
# Brand Name
# FOSSIL             133
# GARMIN             101
# APPLE               86
# FitBit              51
# SAMSUNG             48
# huami               36
# Huawei              26
# Noise               20
# Honor               20
# Fire-Boltt          14
# Zebronics           12
# realme              12
# Xiaomi              10
# Crossbeats           8
# Fastrack             6
# Ptron                5
# boAt                 5
# GOQii                4
# OnePlus              3
# Noise                2
# Oppo                 2
# dizo by realme       2
# LCARE                2
# LAVA                 1
# Infinix              1
# Name: Brand Name, dtype: int64

# %%
#average ratings by Brand
df.groupby('Brand Name')['Rating (Out of 5)'].mean().sort_values(ascending=False).iloc[:10]
# Out:
# Brand Name
# APPLE              4.545349
# OnePlus            4.300000
# dizo by realme     4.250000
# FOSSIL             4.244361
# SAMSUNG            4.229167
# Honor              4.195000
# FitBit             4.186275
# Xiaomi             4.170000
# Huawei             4.161538
# huami              4.152778
# Name: Rating (Out of 5), dtype: float64

# %%
# Rating vs Selling Price
fig, ax = plt.subplots(figsize=(15,3))
ax = sns.stripplot(x="Rating (Out of 5)", y="Selling Price", data=df)

# %%
# Brandwise Mean Selling prices
df.groupby('Brand Name')['Average Battery Life (in days)'].mean().sort_values(ascending=False).iloc[:10]
# Out:
# Brand Name
# GARMIN             16.960396
# huami              16.055556
# Oppo               14.000000
# Xiaomi             12.500000
# dizo by realme     12.000000
# SAMSUNG            11.812500
# Honor              11.750000
# Huawei             11.307692
# Crossbeats         10.500000
# realme             10.500000
# Name: Average Battery Life (in days), dtype: float64

# %%
sns.set_style("white")
sns.displot(df, x='Selling Price',bins=[5000,10000,20000,30000,40000,50000],color='#fd6c9e')
sns.displot(df, x='Original Price',bins=[5000,10000,20000,30000,40000,50000],color='#ff8243')

# %%
# color
df['Color'].groupby(df['Color']).count().sort_values(ascending=False).iloc[:10]
# Out:
# Color
# Black        199
# Blue          33
# Silver        26
# Grey          22
# Gold          21
# White         20
# Brown         15
# Red           11
# Black          8
# Pink Sand      7
# Name: Color, dtype: int64

# %%
# color
df['Strap Material'].groupby(df['Strap Material']).count().sort_values(ascending=False).iloc[:10]
# Out:
# Strap Material
# Silicone                      270
# Stainless Steel                97
# Leather                        61
# Aluminium                      57
# Elastomer                      45
# Thermoplastic polyurethane     35
# Plastic                        16
# Rubber                         14
# Nylon                          12
# Fabric                          1
# Name: Strap Material, dtype: int64

# %%
# Brandwise Mean Selling prices
df.groupby('Brand Name')['Selling Price'].mean().sort_values(ascending=False).apply(np.ceil)
# Out:
# Brand Name
# APPLE              49414.0
# GARMIN             35039.0
# SAMSUNG            22902.0
# Oppo               16490.0
# Huawei             15875.0
# FitBit             14019.0
# FOSSIL             13825.0
# huami               7548.0
# OnePlus             6933.0
# Honor               5510.0
# realme              4403.0
# Xiaomi              4101.0
# boAt                3898.0
# Fire-Boltt          3742.0
# Crossbeats          3573.0
# Noise               3415.0
# dizo by realme      3249.0
# GOQii               3124.0
# Zebronics           2635.0
# LCARE               2347.0
# LAVA                1999.0
# Noise               1949.0
# Fastrack            1755.0
# Infinix             1499.0
# Ptron               1109.0
# Name: Selling Price, dtype: float64

# %%
#Box plot to denote average selling prices
fig, ax = plt.subplots(figsize=(22,5))
ax = sns.boxplot(x="Brand Name", y="Original Price", data=df)

# %%
fig, ax = plt.subplots(figsize=(22,5))
ax = sns.stripplot(y="Selling Price", x="Brand Name", data=df)

# %%
fig, ax = plt.subplots(figsize=(22,5))
ax = sns.stripplot(y="Original Price", x="Brand Name", data=df)

# %% [markdown]
# <h3 style="font-family: Trebuchet MS;background-color:#f7a072;color:#3a0ca3;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 15px 50px;letter-spacing: 2px;"><strong><centre>If you found this notebook useful, please Upvote. Thanks!  </centre></strong></h3>
